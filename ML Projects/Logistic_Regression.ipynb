# %%
import numpy as np

# %% [markdown]
# Work flow of LOgistic Regression
#
# STEP 1 :Set learning Rate and No of iterations;Iniate Random Weight and bias value.
# STEP 2 : Build logistic regression function (sigmoid Function)
#
# STEP 3 : Update the parameters using gradient descent
#
# Finally we'll get the best model as it has minimum cost function
#
# STEp 4 : build "Predict" function to determine the class of the data point

# %%
class Logistic_regression():
  #declaring (hyper parameters) learning rate ,noof iterations
  def __init__(self,learning_rate,no_of_iterations):
    self.learning_rate=learning_rate
    self.no_of_iterations = no_of_iterations

  #fit function to train the model with dataset
  def fit(self,x,y):
    # m => Number of data points in the dataset (Rows)
    # n => Number of input features in the dataset (Columns)
    self.m,self.n = x.shape
    #initializing weight and bias values
    self.w=np.zeros(self.n)
    self.b=0
    self.x=x
    self.y=y

    #gradient decent algorithm for optimization
    for i in range(self.no_of_iterations):
      self.update_weight()

  #function to update the weights
  def update_weight(self):
    #y_hat formula(sigmoid function)
    y_hat = 1/(1+ np.exp (-( self.x.dot ( self.w ) + self.b))) #wx+b

    #derivatives
    dw = (1/self.m)*np.dot(self.x.T,(y_hat - self.y))
    db = (1/self.m)*np.sum(y_hat - self.y)

    #updating weight and bias using gradient decent
    self.w=self.w - self.learning_rate * dw
    self.b = self.b -self.learning_rate * db
  #writing the sigmoid equation and decision boundary
  def predict(self,x):
    y_prediction = 1/(1+np.exp(-(x.dot(self.w)+self.b)))
    y_prediction = np.where(y_prediction > 0.5,1,0)
    return y_prediction

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('/content/diabetes.csv')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.shape
# Out:
# (768, 9)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
df['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
df.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
features = df.drop(columns='Outcome',axis=1)
target=df['Outcome']

# %%
print(features)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
print(target)
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
#standardization
scaler = StandardScaler()

# %%
scaler.fit(features)
# Out:
# StandardScaler()

# %%
std_data = scaler.transform(features)

# %%
features=std_data

# %%
x_train,x_test,y_train,y_test =train_test_split(features,target,test_size=0.2,random_state=2)

# %%
print(features.shape,x_train.shape,x_test.shape)
# Out:
# (768, 8) (614, 8) (154, 8)

# %%
classifier = Logistic_regression(learning_rate =0.01,no_of_iterations=1000)

# %%
classifier.fit(x_train,y_train)

# %%
#Model Evaluation
#Accuracy SCore
#Accuracy on trainig data
Acc_train =classifier.predict(x_train)
training_data_accuracy = accuracy_score(y_train,Acc_train)

# %%
print("Accuracy on training data : ",training_data_accuracy)
# Out:
# Accuracy on training data :  0.7768729641693811

# %%
#Accuracy on testing data
x_test_prediction =classifier.predict(x_test)
testing_data_accuracy = accuracy_score(y_test,x_test_prediction)

# %%
print("Testing data accuracy : ",testing_data_accuracy)
# Out:
# Testing data accuracy :  0.7662337662337663

# %%
input_data = [11,143,94,33,146,36.6,0.254,51]

#changing inp_data to numpy aray
inp_to_numpy = np.asarray(input_data)

#reshape the array as we are predictinf one instance
inp_reshaped = inp_to_numpy.reshape(1,-1)

#standardizing the input data
std_data =scaler.transform(inp_reshaped)
print(std_data)

prediction = classifier.predict(std_data)
print(prediction)

if (prediction[0]==0):
  print("The person is not diabetic")
else:
  print("The person is diabetic")
# Out:
# [[ 2.12477957  0.69183807  1.28699125  0.7818138   0.57481223  0.58477051
#   -0.65801229  1.51108316]]
# [1]
# The person is diabetic
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
